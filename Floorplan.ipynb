# %%
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
im = plt.imread("C:\\Users\\jenny.kim-es\\Downloads\\Floorplan.jpg")
fig, ax = plt.subplots()
im = ax.imshow(im, extent=[0, 100, 0, 100])
x = np.array(range(300))
#ax.plot(x, x, ls='dotted', linewidth=2, color='red')

x_arr = np.array([50, 70])
y_arr = np.array([50, 25])
ax.scatter(x_arr,y_arr, color='green', s=40)
Sensor_name = ['B2_1', 'B2_2']
plt.show()
